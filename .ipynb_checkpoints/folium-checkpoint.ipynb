# %%
import folium

poa = [-30.0346,-51.2177]
sp = [-23.5505, -46.6333]
rj = [-22.9068, -43.1729]
cr = [-25.4290, -49.2671]
bh = [-19.9173, -43.9345]

mapa = folium.Map(location=[sp[0],sp[1]], zoom_start=5)

folium.Marker([poa[0],poa[1]], popup='Porto Alegre, RS, Brasil', icon=folium.Icon(color='lightblue')).add_to(mapa)
folium.Marker([sp[0],sp[1]], popup='São Paulo, SP, Brasil', icon=folium.Icon(color='purple')).add_to(mapa)
folium.Marker([rj[0],rj[1]], popup='Rio de Janeiro, RJ, Brasil', icon=folium.Icon(color='red')).add_to(mapa)
folium.Marker([cr[0],cr[1]], popup='Curitiba, PR, Brasil', icon=folium.Icon(color='black')).add_to(mapa)
folium.Marker([bh[0],bh[1]], popup='Belo Horizonte, MG, Brasil', icon=folium.Icon(color='green', icon_color='white')) .add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad922ffd4875da7ac93f4641f445562f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad922ffd4875da7ac93f4641f445562f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad922ffd4875da7ac93f4641f445562f = L.map(
#                 &quot;map_ad922ffd4875da7ac93f4641f445562f&quot;,
#                 {
#                     center: [-23.5505, -46.6333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_208a8414e55065a5b6d902d55a3ae86f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_208a8414e55065a5b6d902d55a3ae86f.addTo(map_ad922ffd4875da7ac93f4641f445562f);
#
#
#             var marker_4b17a9fd552a5001b0db9e9442b38cbf = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_ad922ffd4875da7ac93f4641f445562f);
#
#
#             var icon_ab7106bc23122f79c5f7591c3a93de5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4b17a9fd552a5001b0db9e9442b38cbf.setIcon(icon_ab7106bc23122f79c5f7591c3a93de5e);
#
#
#         var popup_b4f2d38cb8962acc4ec54d2a4173b311 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0836bf9440d7770421e5b492784eb4e = $(`&lt;div id=&quot;html_b0836bf9440d7770421e5b492784eb4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_b4f2d38cb8962acc4ec54d2a4173b311.setContent(html_b0836bf9440d7770421e5b492784eb4e);
#
#
#
#         marker_4b17a9fd552a5001b0db9e9442b38cbf.bindPopup(popup_b4f2d38cb8962acc4ec54d2a4173b311)
#         ;
#
#
#
#
#             var marker_acc03f32329f731b9ade91b78652d4ef = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_ad922ffd4875da7ac93f4641f445562f);
#
#
#             var icon_ae0efd91a79442769d6fc8ea85ba59df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_acc03f32329f731b9ade91b78652d4ef.setIcon(icon_ae0efd91a79442769d6fc8ea85ba59df);
#
#
#         var popup_0a10bb2e58eefb1e1c29532d4416597e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2b143565ab9fd928cc8f1b819e3ca72 = $(`&lt;div id=&quot;html_d2b143565ab9fd928cc8f1b819e3ca72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_0a10bb2e58eefb1e1c29532d4416597e.setContent(html_d2b143565ab9fd928cc8f1b819e3ca72);
#
#
#
#         marker_acc03f32329f731b9ade91b78652d4ef.bindPopup(popup_0a10bb2e58eefb1e1c29532d4416597e)
#         ;
#
#
#
#
#             var marker_de70068a278f2ca2e7302d9fdeb9e7ed = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_ad922ffd4875da7ac93f4641f445562f);
#
#
#             var icon_2d8616ec9f366fa19005bd71e9443612 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de70068a278f2ca2e7302d9fdeb9e7ed.setIcon(icon_2d8616ec9f366fa19005bd71e9443612);
#
#
#         var popup_921b97860ee04efdfbfe2f3da3fcbd5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84cb566ce4a58792ed36ecf754f3b253 = $(`&lt;div id=&quot;html_84cb566ce4a58792ed36ecf754f3b253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_921b97860ee04efdfbfe2f3da3fcbd5b.setContent(html_84cb566ce4a58792ed36ecf754f3b253);
#
#
#
#         marker_de70068a278f2ca2e7302d9fdeb9e7ed.bindPopup(popup_921b97860ee04efdfbfe2f3da3fcbd5b)
#         ;
#
#
#
#
#             var marker_3b7489662a1e7944c62512f9d9be9dfb = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_ad922ffd4875da7ac93f4641f445562f);
#
#
#             var icon_b024ef3fce9c70ecd4b418b556bb0b88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot
