# %%
import folium

poa = [-30.0346,-51.2177]
sp = [-23.5505, -46.6333]
rj = [-22.9068, -43.1729]
cr = [-25.4290, -49.2671]
bh = [-19.9173, -43.9345]

mapa = folium.Map(location=[sp[0],sp[1]], zoom_start=5)

folium.Marker([poa[0],poa[1]], popup='Porto Alegre, RS, Brasil').add_to(mapa)
folium.Marker([sp[0],sp[1]], popup='São Paulo, SP, Brasil').add_to(mapa)
folium.Marker([rj[0],rj[1]], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)
folium.Marker([cr[0],cr[1]], popup='Curitiba, PR, Brasil').add_to(mapa)
folium.Marker([bh[0],bh[1]], popup='Belo Horizonte, MG, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32fe09d50b9d5ecded40f7aa8e071df6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32fe09d50b9d5ecded40f7aa8e071df6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32fe09d50b9d5ecded40f7aa8e071df6 = L.map(
#                 &quot;map_32fe09d50b9d5ecded40f7aa8e071df6&quot;,
#                 {
#                     center: [-23.5505, -46.6333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fd6641020156c7f47aa8717a39310b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1fd6641020156c7f47aa8717a39310b8.addTo(map_32fe09d50b9d5ecded40f7aa8e071df6);
#
#
#             var marker_f6328f52a1871aa955a859771a0d9cf2 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_32fe09d50b9d5ecded40f7aa8e071df6);
#
#
#         var popup_c2d7b6ec8accaaf9704059a4a6af406b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f961f4bbc388a037524abcf4734297dd = $(`&lt;div id=&quot;html_f961f4bbc388a037524abcf4734297dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_c2d7b6ec8accaaf9704059a4a6af406b.setContent(html_f961f4bbc388a037524abcf4734297dd);
#
#
#
#         marker_f6328f52a1871aa955a859771a0d9cf2.bindPopup(popup_c2d7b6ec8accaaf9704059a4a6af406b)
#         ;
#
#
#
#
#             var marker_da497b0a32b3fde4ac0e7e6a5795a246 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_32fe09d50b9d5ecded40f7aa8e071df6);
#
#
#         var popup_700210f2f4b5b3709e172f562d490b13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e35884ec681f86bad9cc3c9772a9f97b = $(`&lt;div id=&quot;html_e35884ec681f86bad9cc3c9772a9f97b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_700210f2f4b5b3709e172f562d490b13.setContent(html_e35884ec681f86bad9cc3c9772a9f97b);
#
#
#
#         marker_da497b0a32b3fde4ac0e7e6a5795a246.bindPopup(popup_700210f2f4b5b3709e172f562d490b13)
#         ;
#
#
#
#
#             var marker_7500467dae49d860bbcd6eac3cd306de = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_32fe09d50b9d5ecded40f7aa8e071df6);
#
#
#         var popup_767c80644bfbeaf25860769f8dd644c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bc4108a8138a5fd22f9fb1300cba06f = $(`&lt;div id=&quot;html_0bc4108a8138a5fd22f9fb1300cba06f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_767c80644bfbeaf25860769f8dd644c5.setContent(html_0bc4108a8138a5fd22f9fb1300cba06f);
#
#
#
#         marker_7500467dae49d860bbcd6eac3cd306de.bindPopup(popup_767c80644bfbeaf25860769f8dd644c5)
#         ;
#
#
#
#
#             var marker_0da117cea0342bdfeacd1c825698cb3f = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_32fe09d50b9d5ecded40f7aa8e071df6);
#
#
#         var popup_28b5f02e2b64995e210233ae1e29f557 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b24b50a48e5f286d3c3129041e91cba = $(`&lt;div id=&quot;html_0b24b50a48e5f286d3c3129041e91cba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_28b5f02e2b64995e210233ae1e29f557.setContent(html_0b24b50a48e5f286d3c3129041e91cba);
#
#
#
#         marker_0da117cea0342bdfeacd1c825698cb3f.bindPopup(popup_28b5f02e2b64995e210233ae1e29f557)
#         ;
#
#
#
#
#             var marker_650c8636c3eb60088830253422be872b = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_32fe09d50b9d5ecded40f7aa8e071df6);
#
#
#         var popup_8e671e2462c687fec51cad5c14297d95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01b4adc2d0b5e5a62201b0503d396a39 = $(`&lt;div id=&quot;html_01b4adc2d0b5e5a62201b0503d396a39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, MG, Brasil&lt;/div&gt;`)[0];
#                 popup_8e671e2462c687fec51cad5c14297d95.setContent(html_01b4adc2d0b5e5a62201b0503d396a39);
#
#
#
#         marker_650c8636c3eb60088830253422be872b.bindPopup(popup_8e671e2462c687fec51cad5c14297d95)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
