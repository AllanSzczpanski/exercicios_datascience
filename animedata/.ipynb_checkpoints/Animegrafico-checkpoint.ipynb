# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregue o arquivo CSV
df = pd.read_csv("Anime_ratings.csv")

#configurando o RANK
df['Rank'] = pd.to_numeric(df['Rank'], errors='coerce')
df['Rank'].fillna(100, inplace=True)
df['Rank'] = df['Rank'].astype(int)

# Garantir que 'Episodes' seja numérico
df['Episodes'] = pd.to_numeric(df['Episodes'], errors='coerce')
df['Episodes'].fillna(0, inplace=True)  # Substitui valores nulos por 0 ou outro valor apropriado

#filtrando o top 50
top = df[(df['Rank'] <= 50)]
#ordenando pelo rank
top_organizado = top.sort_values(by='Rank')



plt.figure(figsize=(15, 9))
plt.plot(top_organizado['Rank'], top_organizado['Episodes'], marker='o', linestyle='-', color='blue')

# Adicionando rótulos aos pontos
for i in range(top_organizado.shape[0]):
    plt.text(top_organizado['Rank'].iloc[i], top_organizado['Episodes'].iloc[i],
             f'{top_organizado["Episodes"].iloc[i]}', fontsize=9, ha='right')

# Ajustando o limite do eixo y para que os valores estejam em ordem crescente
plt.ylim(top_organizado['Episodes'].min() - 1, top_organizado['Episodes'].max() + 1)

# Configurando o título e os rótulos dos eixos
plt.title('Relação entre Rank e Quantidade de Episódios')
plt.xlabel('Rank')
plt.ylabel('Quantidade de Episódios')

# Exibindo o gráfico
plt.show()
top_organizado
# Out:
#                                                    Title  \
# 20328                   Fullmetal Alchemist: Brotherhood
# 20324                                       Spy x Family
# 20325                 Shingeki no Kyojin Season 3 Part 2
# 20338                                        Steins;Gate
# 20310                                           Gintama°
# 20313                                           Gintama'
# 20308                                 Gintama: The Final
# 20307                             Hunter x Hunter (2011)
# 20319                           Fruits Basket: The Final
# 20305                                Gintama': Enchousen
# 8                                   Ginga Eiyuu Densetsu
# 3                                               Gintama.
# 0             Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                             3-gatsu no Lion 2nd Season
# 4                                         Koe no Katachi
# 7                                                Gintama
# 13                               Violet Evergarden Movie
# 18                                  Clannad: After Story
# 2      Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 26                    Code Geass: Hangyaku no Lelouch R2
# 20317                         Owarimonogatari 2nd Season
# 20315   Gintama.: Shirogane no Tamashii-hen - Kouhan-sen
# 20303                      Kimetsu no Yaiba: Yuukaku-hen
# 20301                                     Kimi no Na wa.
# 20304        Shingeki no Kyojin: The Final Season Part 2
# 20300               Shingeki no Kyojin: The Final Season
# 20312                                            Monster
# 20302                                  Mob Psycho 100 II
# 20295                Gintama.: Shirogane no Tamashii-hen
# 20306                   Kizumonogatari III: Reiketsu-hen
# 20296                                  Shiguang Dailiren
# 20299  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...
# 20309                                 Kingdom 3rd Season
# 20293                                 Kingdom 4th Season
# 20290                   Monogatari Series: Second Season
# 20298                      Sen to Chihiro no Kamikakushi
# 20311                                       Cowboy Bebop
# 20288    Mushoku Tensei: Isekai Ittara Honki Dasu Part 2
# 20291                                           Odd Taxi
# 20284  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...
# 15                         Mushishi Zoku Shou 2nd Season
# 11                                        Hajime no Ippo
# 10                                          Vinland Saga
# 14                                             86 Part 2
# 12     Fate/stay night Movie: Heaven's Feel - III. Sp...
# 22                                       Ashita no Joe 2
# 19                                    Mushishi Zoku Shou
# 9      Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 5                             Mo Dao Zu Shi: Wanjie Pian
# 6                        Code Geass: Hangyaku no Lelouch
#
#                                                   Genres  Rank  Popularity  \
# 20328                     Action,Adventure,Drama,Fantasy     1           3
# 20324                                      Action,Comedy     2         255
# 20325                                       Action,Drama     3          31
# 20338                              Drama,Sci-Fi,Suspense     4          13
# 20310                               Action,Comedy,Sci-Fi     5         338
# 20313                               Action,Comedy,Sci-Fi     6         382
# 20308                         Action,Comedy,Drama,Sci-Fi     7        1735
# 20307                           Action,Adventure,Fantasy     8          10
# 20319                         Drama,Romance,Supernatural     9         547
# 20305                               Action,Comedy,Sci-Fi    10         696
# 8                                           Drama,Sci-Fi    11         700
# 3                                   Action,Comedy,Sci-Fi    12         735
# 0                                        Comedy,Suspense    13         404
# 1                                    Drama,Slice of Life    14         533
# 4                                                    NaN    15          19
# 7                                   Action,Comedy,Sci-Fi    16         127
# 13                           Drama,Fantasy,Slice of Life    17         422
# 18                            Drama,Romance,Supernatural    18         105
# 2                                   Action,Comedy,Sci-Fi    19         939
# 26                                   Action,Drama,Sci-Fi    20          47
# 20317                        Comedy,Mystery,Supernatural    21         537
# 20315                               Action,Comedy,Sci-Fi    22        1191
# 20303                                     Action,Fantasy    23         151
# 20301                                 Drama,Supernatural    24          11
# 20304                                       Action,Drama    25         158
# 20300                                       Action,Drama    26          46
# 20312                             Drama,Mystery,Suspense    27         155
# 20302                         Action,Comedy,Supernatural    28          85
# 20295                               Action,Comedy,Sci-Fi    29        1086
# 20306                        Action,Mystery,Supernatural    30         457
# 20296                                 Drama,Supernatural    31         957
# 20299                                                NaN    32         111
# 20309                                                NaN    33        2222
# 20293                                                NaN    34        3954
# 20290                Comedy,Mystery,Romance,Supernatural    35         273
# 20298               Adventure,Award Winning,Supernatural    36          43
# 20311                                      Action,Sci-Fi    37          42
# 20288                                Drama,Fantasy,Ecchi    38         302
# 20291                                                NaN    39         638
# 20284                                                NaN    40        1143
# 15     Adventure,Fantasy,Mystery,Slice of Life,Supern...    41         827
# 11                                                   NaN    42         376
# 10                                Action,Adventure,Drama    43         102
# 14                                   Action,Drama,Sci-Fi    44         647
# 12                           Action,Fantasy,Supernatural    45         724
# 22                     Action,Drama,Slice of Life,Sports    46        2917
# 19     Adventure,Fantasy,Mystery,Slice of Life,Supern...    47         731
# 9                                   Action,Drama,Romance    48         763
# 5                              Action,Drama,Supernatural    49        2505
# 6                                    Action,Drama,Sci-Fi    50          17
#
#        Score  Episodes   Episode length Release Date
# 20328   9.14      64.0  24 min. per ep.  Spring 2009
# 20324   9.08      12.0  24 min. per ep.  Spring 2022
# 20325   9.08      10.0  23 min. per ep.  Spring 2019
# 20338   9.08      24.0  24 min. per ep.  Spring 2011
# 20310   9.08      51.0  24 min. per ep.  Spring 2015
# 20313   9.05      51.0  24 min. per ep.  Spring 2011
# 20308   9.05       1.0    1 hr. 44 min.          NaN
# 20307   9.05     148.0  23 min. per ep.    Fall 2011
# 20319   9.04      13.0  23 min. per ep.  Spring 2021
# 20305   9.04      13.0  24 min. per ep.    Fall 2012
# 8       9.03     110.0  26 min. per ep.          NaN
# 3       8.99      12.0  24 min. per ep.  Winter 2017
# 0       8.99      12.0  23 min. per ep.  Spring 2022
# 1       8.96      22.0  25 min. per ep.    Fall 2017
# 4       8.96       1.0    2 hr. 10 min.          NaN
# 7       8.95     201.0  24 min. per ep.  Spring 2006
# 13      8.95       1.0    2 hr. 20 min.          NaN
# 18      8.94      24.0  24 min. per ep.    Fall 2008
# 2       8.93       1.0    1 hr. 50 min.          NaN
# 26      8.91      25.0  24 min. per ep.  Spring 2008
# 20317   8.90       7.0  22 min. per ep.  Summer 2017
# 20315   8.88      14.0  24 min. per ep.  Summer 2018
# 20303   8.88      11.0  26 min. per ep.  Winter 2022
# 20301   8.87       1.0    1 hr. 46 min.          NaN
# 20304   8.87      12.0  23 min. per ep.  Winter 2022
# 20300   8.85      16.0  23 min. per ep.  Winter 2021
# 20312   8.83      74.0  24 min. per ep.  Spring 2004
# 20302   8.81      13.0  24 min. per ep.  Winter 2019
# 20295   8.81      12.0  24 min. per ep.  Winter 2018
# 20306   8.80       1.0    1 hr. 23 min.          NaN
# 20296   8.80      11.0  23 min. per ep.          NaN
# 20299   8.79      10.0  24 min. per ep.    Fall 2016
# 20309   8.79      26.0  25 min. per ep.  Spring 2020
# 20293   8.79      26.0  24 min. per ep.  Spring 2022
# 20290   8.78      26.0  25 min. per ep.  Summer 2013
# 20298   8.78       1.0     2 hr. 4 min.          NaN
# 20311   8.76      26.0  24 min. per ep.  Spring 1998
# 20288   8.75      12.0  23 min. per ep.    Fall 2021
# 20291   8.75      13.0  23 min. per ep.  Spring 2021
# 20284   8.75      12.0  24 min. per ep.  Winter 2017
# 15      8.74      10.0  23 min. per ep.    Fall 2014
# 11      8.74      75.0  23 min. per ep.    Fall 2000
# 10      8.73      24.0  24 min. per ep.  Summer 2019
# 14      8.72      12.0  23 min. per ep.    Fall 2021
# 12      8.72       1.0     2 hr. 2 min.          NaN
# 22      8.71      47.0  24 min. per ep.    Fall 1980
# 19      8.71      10.0  24 min. per ep.  Spring 2014
# 9       8.71       4.0  30 min. per ep.          NaN
# 5       8.70      12.0  24 min. per ep.          NaN
# 6       8.70      25.0  24 min. per ep.    Fall 2006
